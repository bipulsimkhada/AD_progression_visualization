# %%
import sys
import os
from pathlib import Path

sys.path.append(str(Path.cwd().parents[0]))

# %load_ext autoreload
# %autoreload 2

# %%
from experiments.analysis import get_results

df_loss_s1 = get_results("../results/cv/loss", "s1")
df_loss_s1
# Out:
#               name overall_accuracy overall_balanced_accuracy  \
# 0  s1_severity_100  0.8758 ± 0.0221           0.8721 ± 0.0204
# 1  s1_severity_000  0.8741 ± 0.0238           0.8693 ± 0.0225
# 2  s1_severity_025  0.8699 ± 0.0235           0.8679 ± 0.0211
# 3  s1_severity_075  0.8697 ± 0.0270           0.8671 ± 0.0249
# 4  s1_severity_050  0.8638 ± 0.0280           0.8591 ± 0.0294
#
#    stable_accuracy stable_balanced_accuracy converter_accuracy  \
# 0  0.9160 ± 0.0225          0.9096 ± 0.0224    0.5894 ± 0.0243
# 1  0.9128 ± 0.0229          0.9056 ± 0.0226    0.5987 ± 0.0381
# 2  0.9084 ± 0.0251          0.9036 ± 0.0243    0.5955 ± 0.0293
# 3  0.9085 ± 0.0273          0.9023 ± 0.0256    0.5936 ± 0.0312
# 4  0.9022 ± 0.0303          0.8947 ± 0.0323    0.5904 ± 0.0194
#
#   converter_balanced_accuracy converter_T0_accuracy converter_T6_accuracy  \
# 0             0.5580 ± 0.0491       0.7036 ± 0.0918       0.6408 ± 0.0436
# ...

# %%
from experiments.analysis import get_results

df_loss_ss2 = get_results("../results/cv/loss", "s2")
df_loss_ss2
# Out:
#                   name overall_accuracy overall_balanced_accuracy  \
# 0    s2_transition_300  0.8760 ± 0.0228           0.8719 ± 0.0221
# 1    s2_transition_200  0.8754 ± 0.0225           0.8722 ± 0.0182
# 2    s2_transition_700  0.8741 ± 0.0236           0.8706 ± 0.0237
# 3    s2_transition_050  0.8735 ± 0.0243           0.8677 ± 0.0223
# 4    s2_transition_075  0.8724 ± 0.0167           0.8683 ± 0.0126
# 5    s2_transition_000  0.8723 ± 0.0229           0.8694 ± 0.0207
# 6   s2_transition_1000  0.8721 ± 0.0271           0.8679 ± 0.0246
# 7    s2_transition_600  0.8719 ± 0.0238           0.8695 ± 0.0223
# 8    s2_transition_150  0.8712 ± 0.0258           0.8661 ± 0.0235
# 9    s2_transition_025  0.8701 ± 0.0247           0.8672 ± 0.0197
# 10   s2_transition_500  0.8694 ± 0.0283           0.8650 ± 0.0278
# 11   s2_transition_400  0.8691 ± 0.0194           0.8636 ± 0.0162
# 12   s2_transition_100  0.8523 ± 0.0699           0.8479 ± 0.0703
#
# ...

# %%
from experiments.analysis import get_results

df_loss_s3 = get_results("../results/cv/loss", "s3")
df_loss_s3
# Out:
#                        name overall_accuracy overall_balanced_accuracy  \
# 0             s3_time_equal  0.8781 ± 0.0195           0.8734 ± 0.0195
# 1       s3_time_progressive  0.8765 ± 0.0252           0.8729 ± 0.0233
# 2  s3_time_progressive_mild  0.8701 ± 0.0242           0.8661 ± 0.0227
# 3   s3_time_late_focus_0_24  0.8541 ± 0.0299           0.8483 ± 0.0284
#
#    stable_accuracy stable_balanced_accuracy converter_accuracy  \
# 0  0.9148 ± 0.0214          0.9078 ± 0.0213    0.6170 ± 0.0214
# 1  0.9129 ± 0.0244          0.9069 ± 0.0233    0.6175 ± 0.0400
# 2  0.9057 ± 0.0270          0.8990 ± 0.0265    0.6162 ± 0.0305
# 3  0.8915 ± 0.0300          0.8808 ± 0.0297    0.5872 ± 0.0439
#
#   converter_balanced_accuracy converter_T0_accuracy converter_T6_accuracy  \
# 0             0.5842 ± 0.0420       0.7183 ± 0.0865       0.6461 ± 0.0508
# 1             0.5996 ± 0.0520       0.7147 ± 0.0679       0.6426 ± 0.0548
# ...

# %%
# from experiments.analysis import get_results

# df_loss_s4 = get_results("../results/cv/loss", "s4")
# df_loss_s4
# Out:
#             name overall_accuracy overall_balanced_accuracy  stable_accuracy  \
# 0  s4_loss_huber  0.8779 ± 0.0234           0.8734 ± 0.0201  0.9143 ± 0.0239
# 1    s4_loss_mse  0.8766 ± 0.0224           0.8725 ± 0.0190  0.9119 ± 0.0213
# 2    s4_loss_mae  0.8678 ± 0.0202           0.8642 ± 0.0190  0.9111 ± 0.0210
#
#   stable_balanced_accuracy converter_accuracy converter_balanced_accuracy
# 0          0.9078 ± 0.0219    0.6184 ± 0.0296             0.5856 ± 0.0428
# 1          0.9057 ± 0.0192    0.6259 ± 0.0336             0.5998 ± 0.0474
# 2          0.9040 ± 0.0206    0.5591 ± 0.0196             0.5493 ± 0.0383

# %%
from experiments.analysis import get_results

df_loss_s4 = get_results("../results/cv/loss", "s4")
df_loss_s4
# Out:
#             name overall_accuracy overall_balanced_accuracy  stable_accuracy  \
# 0    s4_loss_mae  0.8742 ± 0.0230           0.8702 ± 0.0206  0.9065 ± 0.0207
# 1  s4_loss_huber  0.8737 ± 0.0203           0.8708 ± 0.0178  0.8990 ± 0.0221
# 2    s4_loss_mse  0.8595 ± 0.0293           0.8572 ± 0.0281  0.8824 ± 0.0301
#
#   stable_balanced_accuracy converter_accuracy converter_balanced_accuracy  \
# 0          0.8997 ± 0.0199    0.6440 ± 0.0519             0.6090 ± 0.0611
# 1          0.8938 ± 0.0197    0.6932 ± 0.0343             0.6520 ± 0.0398
# 2          0.8778 ± 0.0301    0.6960 ± 0.0361             0.6533 ± 0.0434
#
#   converter_T0_accuracy converter_T6_accuracy converter_T12_accuracy  \
# 0       0.7781 ± 0.0874       0.6518 ± 0.0619        0.5958 ± 0.0793
# 1       0.8359 ± 0.0863       0.6498 ± 0.0510        0.6083 ± 0.0517
# 2       0.8616 ± 0.0542       0.6335 ± 0.0418        0.5864 ± 0.0507
#
#   converter_T24_accuracy
# 0        0.5503 ± 0.1017
# 1        0.6788 ± 0.0628
# ...

# %%
from visualizer.adpg import adpg_visualizer

adpg_visualizer(
    [[0,1,0],[0,1,0],[0,0,1],[0,0,1]],
    [[0,0.7,0.3],[0,0.4,0.6],[0,0.2,0.8],[0,0.05,0.95]],
    [[0,0.01,0],[0,0.015,0],[0,0,0.012],[0,0,0.081]],
    1,
    "m06"
)
# Out:
# findfont: Failed to find font weight semibold for DejaVu Sans, now using 700.
# (<Figure size 700x500 with 1 Axes>,
#  <Axes: title={'center': 'RID: 1, VISCODE: m06'}>)
